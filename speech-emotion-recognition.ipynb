# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Import modules

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
paths= []
labels = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
labels[:5]
# Out:
# ['fear', 'fear', 'fear', 'fear', 'fear']

# %%
paths[:5]
# Out:
# ['/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_home_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_youth_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_near_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_search_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_pick_fear.wav']

# %%
## Create a dataFrame
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech label
# 0  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 1  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 2  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 3  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 4  /kaggle/input/toronto-emotional-speech-set-tes...  fear

# %%
df['label'].value_counts()
# Out:
# fear       800
# angry      800
# disgust    800
# neutral    800
# sad        800
# ps         800
# happy      800
# Name: label, dtype: int64

# %% [markdown]
# ## Data Exploration

# %%
sns.countplot(x=df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
def waveplot(data,sr,emotion):
    plt.figure(figsize=(14,4))
    plt.title(emotion, size=20)
    librosa.display.waveplot(data, sr=sr)
    plt.show()
    
def spectogram(data,sr,emotion):
    x = librosa.stft(data) 
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis = 'time', y_axis = 'hz')
    plt.colorbar()

# %%
emotion = 'fear'
path = df['speech'][df['label']==emotion][2]
data,sampling_rate = librosa.load(path)
librosa.display.waveshow(data, sr=sampling_rate)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[1]
data,sampling_rate = librosa.load(path)
librosa.display.waveshow(data, sr=sampling_rate)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data,sampling_rate = librosa.load(path)
librosa.display.waveshow(data, sr=sampling_rate)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data,sampling_rate = librosa.load(path)
librosa.display.waveshow(data, sr=sampling_rate)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data,sampling_rate = librosa.load(path)
librosa.display.waveshow(data, sr=sampling_rate)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data,sampling_rate = librosa.load(path)
librosa.display.waveshow(data, sr=sampling_rate)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data,sampling_rate = librosa.load(path)
librosa.display.waveshow(data, sr=sampling_rate)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Feature Extraction

# %%
def extract_mfcc(filename):
    y,sr = librosa.load(filename, duration =3,offset=0.5)
    mfcc= np.mean(librosa.feature.mfcc(y=y,sr=sr,n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-285.73727   ,   85.78295   ,   -2.1689112 ,   22.125532  ,
#         -14.757395  ,   11.051346  ,   12.412449  ,   -3.0002618 ,
#           1.0844991 ,   11.078272  ,  -17.41966   ,   -8.093213  ,
#           6.5879726 ,   -4.2209535 ,   -9.15508   ,    3.52148   ,
#         -13.186381  ,   14.078853  ,   19.66973   ,   22.725618  ,
#          32.57464   ,   16.325035  ,   -3.8427293 ,    0.89629656,
#         -11.239262  ,    6.653462  ,   -2.5883696 ,   -7.7140164 ,
#         -10.941658  ,   -2.4007547 ,   -5.281288  ,    4.271157  ,
#         -11.202216  ,   -9.024621  ,   -3.6669848 ,    4.869744  ,
#          -1.6027985 ,    2.5600514 ,   11.454374  ,   11.233449  ],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-285.73727, 85.78295, -2.1689112, 22.125532, ...
# 1       [-348.34332, 35.193233, -3.841328, 14.658875, ...
# 2       [-340.11435, 53.796444, -14.267782, 20.884027,...
# 3       [-306.63422, 21.259708, -4.4110823, 6.4871554,...
# 4       [-344.7548, 46.329193, -24.171413, 19.392921, ...
#                               ...
# 5595    [-374.3952, 60.864998, 0.025059083, 8.431058, ...
# 5596    [-313.96478, 39.847843, -5.6493053, -3.867575,...
# 5597    [-357.54886, 77.886055, -15.224756, 2.194633, ...
# 5598    [-353.1474, 101.68391, -14.175896, -12.037376,...
# 5599    [-389.4595, 54.042767, 1.346998, -1.4258983, -...
# Name: speech, Length: 5600, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (5600, 40)

# %%
## input split
X=np.expand_dims(X, -1)
X.shape
# Out:
# (5600, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y =y.toarray()

# %%
y.shape
# Out:
# (5600, 7)

# %% [markdown]
# # Using LSTM Model

# %%
from keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from keras.layers import Dense,LSTM,Dropout

model= Sequential([
    LSTM(123,return_sequences= False, input_shape=(40,1)),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32,activation = 'relu'),
    Dropout(0.2),
    Dense(7,activation = 'softmax')
])
#sgd = SGD(lr=0, decay=1e-6, momentum=0.9,nesterov = True)
#model.compile(loss='sparse_categorical_crossentrophy',optimizer = sgd,metrics=['accuracy'])
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 123)               61500
#
#  dense (Dense)               (None, 64)                7936
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 71,747
# Trainable params: 71,747
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X, y, validation_split = 0.2, epochs = 50, batch_size = 64, shuffle = True,verbose=True)
# Out:
# Epoch 1/50
# 70/70 [==============================] - 7s 61ms/step - loss: 1.0632 - accuracy: 0.6328 - val_loss: 0.7624 - val_accuracy: 0.7000
# Epoch 2/50
# 70/70 [==============================] - 4s 53ms/step - loss: 0.3907 - accuracy: 0.8625 - val_loss: 0.4129 - val_accuracy: 0.8500
# Epoch 3/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.2674 - accuracy: 0.9156 - val_loss: 0.2149 - val_accuracy: 0.9464
# Epoch 4/50
# 70/70 [==============================] - 4s 53ms/step - loss: 0.1967 - accuracy: 0.9442 - val_loss: 0.2686 - val_accuracy: 0.9205
# Epoch 5/50
# 70/70 [==============================] - 4s 56ms/step - loss: 0.1344 - accuracy: 0.9585 - val_loss: 0.1173 - val_accuracy: 0.9643
# Epoch 6/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.1371 - accuracy: 0.9625 - val_loss: 0.1692 - val_accuracy: 0.9366
# Epoch 7/50
# 70/70 [==============================] - 4s 57ms/step - loss: 0.0944 - accuracy: 0.9728 - val_loss: 0.0649 - val_accuracy: 0.9804
# Epoch 8/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.1083 - accuracy: 0.9676 - val_loss: 0.2746 - val_accuracy: 0.9134
# Epoch 9/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.1062 - accuracy: 0.9690 - val_loss: 0.0588 - val_accuracy: 0.9830
# Epoch 10/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.0927 - accuracy: 0.9737 - val_loss: 0.0523 - val_accuracy: 0.9848
# Epoch 11/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.0530 - accuracy: 0.9859 - val_loss: 0.0590 - val_accuracy: 0.9821
# Epoch 12/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.0568 - accuracy: 0.9821 - val_loss: 0.0618 - val_accuracy: 0.9795
# Epoch 13/50
# 70/70 [==============================] - 4s 61ms/step - loss: 0.0496 - accuracy: 0.9859 - val_loss: 0.0561 - val_accuracy: 0.9804
# Epoch 14/50
# 70/70 [==============================] - 4s 57ms/step - loss: 0.0480 - accuracy: 0.9859 - val_loss: 0.0287 - val_accuracy: 0.9911
# Epoch 15/50
# 70/70 [==============================] - 4s 56ms/step - loss: 0.0579 - accuracy: 0.9826 - val_loss: 0.0463 - val_accuracy: 0.9830
# Epoch 16/50
# 70/70 [==============================] - 4s 60ms/step - loss: 0.0442 - accuracy: 0.9875 - val_loss: 0.0558 - val_accuracy: 0.9821
# Epoch 17/50
# 70/70 [==============================] - 4s 54ms/step - loss: 0.0352 - accuracy: 0.9902 - val_loss: 0.0593 - val_accuracy: 0.9804
# Epoch 18/50
# 70/70 [==============================] - 4s 59ms/step - loss: 0.0311 - accuracy: 0.9902 - val_loss: 0.0723 - val_accuracy: 0.9696
# Epoch 19/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.0300 - accuracy: 0.9911 - val_loss: 0.0248 - val_accuracy: 0.9884
# Epoch 20/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.0432 - accuracy: 0.9893 - val_loss: 0.0259 - val_accuracy: 0.9929
# Epoch 21/50
# 70/70 [==============================] - 4s 58ms/step - loss: 0.0270 - accuracy: 0.9922 - val_loss: 0.0519 - val_accuracy: 0.9821
# Epoch 22/50
# 70/70 [==============================] - 4s 57ms/step - loss: 0.0273 - accuracy: 0.9926 - val_loss: 0.0559 - val_accuracy: 0.9795
# Epoch 23/50
# 70/70 [==============================] - 4s 59ms/step - loss: 0.0471 - accuracy: 0.9873 - val_loss: 0.0855 - val_accuracy: 0.9714
# Epoch 24/50
# 70/70 [==============================] - 4s 57ms/step - loss: 0.0346 - accuracy: 0.9906 - val_loss: 0.0199 - val_accuracy: 0.9946
# Epoch 25/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.0295 - accuracy: 0.9915 - val_loss: 0.0234 - val_accuracy: 0.9902
# Epoch 26/50
# 70/70 [==============================] - 4s 54ms/step - loss: 0.0134 - accuracy: 0.9964 - val_loss: 0.0244 - val_accuracy: 0.9875
# Epoch 27/50
# 70/70 [==============================] - 4s 54ms/step - loss: 0.0276 - accuracy: 0.9937 - val_loss: 0.0135 - val_accuracy: 0.9955
# Epoch 28/50
# 70/70 [==============================] - 4s 56ms/step - loss: 0.0517 - accuracy: 0.9855 - val_loss: 0.0304 - val_accuracy: 0.9893
# Epoch 29/50
# 70/70 [==============================] - 4s 57ms/step - loss: 0.0263 - accuracy: 0.9929 - val_loss: 0.0240 - val_accuracy: 0.9920
# Epoch 30/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.0155 - accuracy: 0.9960 - val_loss: 0.0104 - val_accuracy: 0.9964
# Epoch 31/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.0510 - accuracy: 0.9873 - val_loss: 0.0279 - val_accuracy: 0.9893
# Epoch 32/50
# 70/70 [==============================] - 4s 52ms/step - loss: 0.0247 - accuracy: 0.9929 - val_loss: 0.0073 - val_accuracy: 0.9973
# Epoch 33/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.0234 - val_accuracy: 0.9893
# Epoch 34/50
# 70/70 [==============================] - 4s 59ms/step - loss: 0.0182 - accuracy: 0.9949 - val_loss: 0.1967 - val_accuracy: 0.9500
# Epoch 35/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.0177 - accuracy: 0.9955 - val_loss: 0.0456 - val_accuracy: 0.9848
# Epoch 36/50
# 70/70 [==============================] - 4s 56ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.0057 - val_accuracy: 0.9973
# Epoch 37/50
# 70/70 [==============================] - 4s 60ms/step - loss: 0.0205 - accuracy: 0.9953 - val_loss: 0.3297 - val_accuracy: 0.9348
# Epoch 38/50
# 70/70 [==============================] - 4s 57ms/step - loss: 0.0300 - accuracy: 0.9926 - val_loss: 0.0209 - val_accuracy: 0.9884
# Epoch 39/50
# 70/70 [==============================] - 4s 58ms/step - loss: 0.0194 - accuracy: 0.9942 - val_loss: 0.0175 - val_accuracy: 0.9946
# Epoch 40/50
# 70/70 [==============================] - 4s 55ms/step - loss: 0.0345 - accuracy: 0.9906 - val_loss: 0.0080 - val_accuracy: 0.9973
# Epoch 41/50
# 70/70 [==============================] - 4s 54ms/step - loss: 0.0211 - accuracy: 0.9951 - val_loss: 0.0184 - val_accuracy: 0.9982
# Epoch 42/50
# 70/70 [==============================] - 4s 60ms/step - loss: 0.0078 - accuracy: 0.9978 - val_loss: 0.0043 - val_accuracy: 0.9991
# Epoch 43/50
# 70/70 [==============================] - 4s 56ms/step - loss: 0.0107 - accuracy: 0.9973 - val_loss: 0.0091 - val_accuracy: 0.9973
# Epoch 44/50
# 70/70 [==============================] - 4s 57ms/step - loss: 0.0161 - accuracy: 0.9967 - val_loss: 0.0713 - val_accuracy: 0.9812
# Epoch 45/50
# 70/70 [==============================] - 4s 57ms/step - loss: 0.0157 - accuracy: 0.9946 - val_loss: 0.0098 - val_accuracy: 0.9964
# Epoch 46/50
# 70/70 [==============================] - 4s 54ms/step - loss: 0.0081 - accuracy: 0.9982 - val_loss: 0.0106 - val_accuracy: 0.9973
# Epoch 47/50
# 70/70 [==============================] - 4s 53ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0071 - val_accuracy: 0.9973
# Epoch 48/50
# 70/70 [==============================] - 4s 56ms/step - loss: 0.0348 - accuracy: 0.9917 - val_loss: 0.0684 - val_accuracy: 0.9759
# Epoch 49/50
# 70/70 [==============================] - 4s 54ms/step - loss: 0.0402 - accuracy: 0.9888 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 50/50
# 70/70 [==============================] - 4s 54ms/step - loss: 0.0059 - accuracy: 0.9993 - val_loss: 0.0027 - val_accuracy: 1.0000

# %% [markdown]
# # Results

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label= 'val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label= 'val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
